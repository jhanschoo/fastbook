# %% [markdown]
# We retrieve an image from imagenette and preview it, and its dimensions.

# %%
from fastai.vision.all import *

path = untar_data(URLs.IMAGENETTE_160)
t = get_image_files(path)
im = Image.open(t[0])
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=283x160>

# %%
im_t = tensor(im)
im_t.shape
# Out:
# torch.Size([160, 283, 3])
